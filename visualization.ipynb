# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.size'] = 9 # This should set the size to 9pt

# %%
df = pd.read_csv('datasets/clean_v1.csv')

# %%
df.head()
sns.set(style="ticks")
sns.set_palette("colorblind")

# %%
sns.scatterplot(data=df,x='altitude',y='ascent_count') #KEEP. Format it properly. (title, legend, axes label + unit
# log of x and y axis + heteroskedastic)
plt.show()

# %%
# drawing a histogram to visualise the distribution of ascent count and height of the munro
### PREF ###
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# by taking appropriate bins into account for the dataset
sns.histplot(df['ascent_count'], ax=ax1,bins='fd')
ax1.set_xlabel('Number of Ascents')
ax1.set_ylabel('Frequency')
ax1.set_title('Distribution of Ascent Count for all munros')

sns.histplot(df['altitude'], ax=ax2,bins='fd')
ax2.set_xlabel('Altitude (m)')
ax2.set_ylabel('Frequency')
ax2.set_title('Distribution of Altitude of the Munros')

sns.histplot(df['rating'], ax=ax3,bins='fd')
ax3.set_xlabel('Rating (out of 5)')
ax3.set_ylabel('Frequency')
ax3.set_title('Distribution of Rating of the Munros')
# not reliable until we factor for number of votes

plt.show()

# %%
# drawing a distplot to visualise the distribution of ascent count and height of the munro
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# by taking appropriate bins into account for the dataset
sns.distplot(df['ascent_count'], ax=ax1,bins='fd')
ax1.set_xlabel('Number of Ascents')
ax1.set_ylabel('Frequency')
ax1.set_title('Distribution of Ascent Count for all munros')

sns.distplot(df['altitude'], ax=ax2,bins='fd')
ax2.set_xlabel('Altitude (m)')
ax2.set_ylabel('Frequency')
ax2.set_title('Distribution of Altitude of the Munros')

sns.distplot(df['rating'], ax=ax3,bins='fd')
ax3.set_xlabel('Rating (out of 5)')
ax3.set_ylabel('Frequency')
ax3.set_title('Distribution of Rating of the Munros') #ADD FORMAT + ACTUAL CURVE (exp dist)

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# getting a heatmap of bivariate distribution
sns.displot(x=df['altitude'],y=df['ascent_count'])
plt.show()

# %%
# getting a contour of distribution
sns.displot(x=df['altitude'],y=df['ascent_count'], kind='kde')
plt.show()
# outlier visible

# %%
# getting a contour of distribution with a rug
# NO NEED - CHOOSE ABOVE TWO
plt.figure(figsize=(30,30))
sns.displot(x=df['altitude'],y=df['ascent_count'], kind='kde', rug=True)
plt.show()
# outlier visible

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                    gridspec_kw={"height_ratios": (.15, .85)})

sns.boxplot(df['ascent_count'], ax=ax_box)
sns.histplot(df['ascent_count'], ax=ax_hist, bins='fd')

ax_box.set(yticks=[])
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                    gridspec_kw={"height_ratios": (.15, .85)})

sns.boxplot(df['altitude'], ax=ax_box)
sns.histplot(df['altitude'], ax=ax_hist, bins='fd')

ax_box.set(yticks=[])
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
