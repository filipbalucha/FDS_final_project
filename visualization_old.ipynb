# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.size'] = 9 # This should set the size to 9pt

# %%
df = pd.read_csv('datasets/clean.csv')
# Out:
#                         name  altitude  ascent_count  rating        region  \
# 0                  Ben Nevis      1345         17902    3.84  Fort William
# 1                 Ben Macdui      1309         10449    3.78    Cairngorms
# 2                  Braeriach      1296          6035    3.95    Cairngorms
# 3                 Cairn Toul      1291          5121    3.86    Cairngorms
# 4      Sgor an Lochain Uaine      1258          4832    3.83    Cairngorms
# ..                       ...       ...           ...     ...           ...
# 277               Carn Aosda       917         11179    2.47    Cairngorms
# 278  Geal-charn (Drumochter)       917          7474    3.00    Cairngorms
# 279         Beinn a' Chleibh       916          6689    2.98        Argyll
# 280           Beinn Teallach       915          3747    3.07  Fort William
# 281                 Ben Vane       915         10463    3.68   Loch Lomond
#
# ...

# %%
df.head()
sns.set(style="ticks")
sns.set_palette("colorblind")

# %%
plt.figure(figsize=(6,4))
# adding transparency to make plot look better
sns.scatterplot(x=df['altitude'],y=df['ascent_count'], label='Munro Ascents', alpha = 0.7)
plt.title('Scatterplot between altitude and number of ascents')
plt.xlabel('Altitude (m)')
plt.ylabel('Number of Ascents (no unit)')
plt.scatter([1345],[17902], label='Ben Nevis', s=40)
b = df.loc[df['name'] == 'Ben Lomond']
plt.scatter(b.altitude, b.ascent_count, label='Ben Lomond', s=40, c = 'r')
plt.legend()
plt.tight_layout() # Can help to fit in space for smaller plots
plt.show()

# %%
# drawing a histogram to visualise the distribution of ascent count and height of the munro
### PREF ###
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))

# by taking appropriate bins into account for the dataset
sns.histplot(df['ascent_count'], ax=ax1,bins='fd', label='Ascent Frequency')
ax1.set_xlabel('Number of Ascents (no unit)')
ax1.set_ylabel('Frequency')
ax1.legend()
ax1.set_title('Munro Ascent Count Distribution')

sns.histplot(df['altitude'], ax=ax2,bins='fd', label='Altitude Frequency')
ax2.legend()
ax2.set_xlabel('Altitude (m)')
ax2.set_ylabel('Frequency')
ax2.set_title('Munro Altitude Distribution')
plt.tight_layout() # Can help to fit in space for smaller plots

plt.show()

# %%
# drawing a distplot to visualise the distribution of ascent count and height of the munro
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# by taking appropriate bins into account for the dataset
sns.distplot(df['ascent_count'], ax=ax1,bins='fd')
ax1.set_xlabel('Number of Ascents')
ax1.set_ylabel('Frequency')
ax1.set_title('Distribution of Ascent Count for all munros')

sns.distplot(df['altitude'], ax=ax2,bins='fd')
ax2.set_xlabel('Altitude (m)')
ax2.set_ylabel('Frequency')
ax2.set_title('Distribution of Altitude of the Munros')

sns.distplot(df['rating'], ax=ax3,bins='fd')
ax3.set_xlabel('Rating (out of 5)')
ax3.set_ylabel('Frequency')
ax3.set_title('Distribution of Rating of the Munros') #ADD FORMAT + ACTUAL CURVE (exp dist)

plt.show()
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# getting a heatmap of bivariate distribution
plt.figure(figsize=(6,4))
ax1 = sns.jointplot(x=df['altitude'],y=df['ascent_count'], kind='hex')
plt.ylabel('Number of Ascents (no unit)')
plt.xlabel('Altitude (m)')
plt.suptitle('Heatmap for Altitude and Ascent Count')
plt.tight_layout()
cbar_ax = ax1.fig.add_axes([1, 0.1, .03, .7])
cb = plt.colorbar(cax = cbar_ax)
cb.set_label('Frequency distribution')
plt.show()

# %%
fig = plt.figure(figsize=(6, 4))
g = sns.jointplot(data=df, x="altitude", y="ascent_count", alpha=0.6)
g.set_axis_labels('Altitude (m)', 'Number of Ascents')
g.fig.suptitle("Joint Distribution - Altitude and Ascents")
g.plot_joint(sns.kdeplot,zorder=0, levels=6)
g.plot_marginals(sns.rugplot, height=-.15, clip_on=False)
sns.set_palette("colorblind")
plt.tight_layout()
plt.show()

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                    gridspec_kw={"height_ratios": (.15, .85)}, figsize=(6,4))
plt.suptitle('Boxplot and Histogram for outlier Munros')
sns.boxplot(df['ascent_count'], ax=ax_box)
sns.histplot(df['ascent_count'], ax=ax_hist, bins='fd', label='Frequency')
ax_hist.set_ylabel('Count')
ax_hist.set_xlabel('Number of Ascents (no unit')
plt.legend()

ax_box.set(yticks=[])
ax_box.set_xlabel('Number of Ascents (no unit)')
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True)
sns.set_palette("colorblind")
plt.tight_layout()
plt.show()
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                    gridspec_kw={"height_ratios": (.15, .85)},figsize=(6,4))
plt.suptitle('Boxplot and Histogram for outlier Munros')
ax_hist.set_ylabel('Frequency')
ax_hist.set_xlabel('Altitude (m)')
sns.boxplot(df['altitude'], ax=ax_box)
sns.histplot(df['altitude'], ax=ax_hist, bins='fd', label='Frequency')
plt.legend()

ax_box.set(yticks=[])
ax_box.set_xlabel('Altitude (m)')
sns.despine(ax=ax_hist)
sns.despine(ax=ax_box, left=True)
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ad6e5521-2329-4ba2-9ce8-c0f71fb15c68' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
